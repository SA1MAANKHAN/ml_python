# %%
from tensorflow import keras
import tensorflow as tf

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("datasets/Titanic/titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sex_to_num= {"Sex":{"male": 1, "female": 0}}

# %%
df_new = df.replace(sex_to_num )

# %%
df_new.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df_new
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df_new.drop(["Ticket","Cabin","Name","PassengerId","Embarked"] , axis = 1 , inplace = True)

# %%
df_new
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 888         0       3    0   NaN      1      2  23.4500
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
data = df_new

# %%
data[data["Age"].isnull()]
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch     Fare
# 5           0       3    1  NaN      0      0   8.4583
# 17          1       2    1  NaN      0      0  13.0000
# 19          1       3    0  NaN      0      0   7.2250
# 26          0       3    1  NaN      0      0   7.2250
# 28          1       3    0  NaN      0      0   7.8792
# ..        ...     ...  ...  ...    ...    ...      ...
# 859         0       3    1  NaN      0      0   7.2292
# 863         0       3    0  NaN      8      2  69.5500
# 868         0       3    1  NaN      0      0   9.5000
# 878         0       3    1  NaN      0      0   7.8958
# 888         0       3    0  NaN      1      2  23.4500
#
# [177 rows x 7 columns]

# %%
data['Age'].fillna(29.699118 , inplace = True)

# %%
data[data.isnull()]
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch  Fare
# 0         NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 1         NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 2         NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 3         NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 4         NaN     NaN  NaN  NaN    NaN    NaN   NaN
# ..        ...     ...  ...  ...    ...    ...   ...
# 886       NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 887       NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 888       NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 889       NaN     NaN  NaN  NaN    NaN    NaN   NaN
# 890       NaN     NaN  NaN  NaN    NaN    NaN   NaN
#
# [891 rows x 7 columns]

# %%
data.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443 -0.549500
# Sex      -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489 -0.182333
# Age      -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191  0.091566
# SibSp    -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500 -0.182333  0.091566  0.159651  0.216225  1.000000

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train = data.drop("Survived" , axis = 1)

# %%
y_train = data["Survived"]

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
data_test = pd.read_csv("datasets/Titanic/titanic_test.csv")

# %%
df_test = data_test.replace(sex_to_num)

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    1
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2            894       2                     Myles, Mr. Thomas Francis    1
# 3            895       3                              Wirz, Mr. Albert    1
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    1
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    0
# 415         1307       3                  Saether, Mr. Simon Sivertsen    1
# 416         1308       3                           Ware, Mr. Frederick    1
# 417         1309       3                      Peter, Master. Michael J    1
#
# ...

# %%
df_test.drop(["Ticket","Cabin","Name","PassengerId","Embarked",] , axis = 1 , inplace = True)

# %%
df_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Survived
# 12        1    0  23.0      1      0   82.2667         1
# 14        1    0  47.0      1      0   61.1750         1
# 24        1    0  48.0      1      3  262.3750         1
# 26        1    0  22.0      0      1   61.9792         1
# 28        1    1  41.0      0      0   30.5000         0
# ..      ...  ...   ...    ...    ...       ...       ...
# 404       1    1  43.0      1      0   27.7208         0
# 405       2    1  20.0      0      0   13.8625         0
# 407       1    1  50.0      1      1  211.5000         0
# 411       1    0  37.0      1      0   90.0000         1
# 414       1    0  39.0      0      0  108.9000         1
#
# [87 rows x 7 columns]

# %%
df_test["Survived"] = y_test

# %%
df_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Survived
# 12        1    0  23.0      1      0   82.2667         1
# 14        1    0  47.0      1      0   61.1750         1
# 24        1    0  48.0      1      3  262.3750         1
# 26        1    0  22.0      0      1   61.9792         1
# 28        1    1  41.0      0      0   30.5000         0
# ..      ...  ...   ...    ...    ...       ...       ...
# 404       1    1  43.0      1      0   27.7208         0
# 405       2    1  20.0      0      0   13.8625         0
# 407       1    1  50.0      1      1  211.5000         0
# 411       1    0  37.0      1      0   90.0000         1
# 414       1    0  39.0      0      0  108.9000         1
#
# [87 rows x 7 columns]

# %%
df_test.dropna(inplace = True)

# %%
df_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare
# 12        1    0  23.0      1      0   82.2667
# 14        1    0  47.0      1      0   61.1750
# 24        1    0  48.0      1      3  262.3750
# 26        1    0  22.0      0      1   61.9792
# 28        1    1  41.0      0      0   30.5000
# ..      ...  ...   ...    ...    ...       ...
# 404       1    1  43.0      1      0   27.7208
# 405       2    1  20.0      0      0   13.8625
# 407       1    1  50.0      1      1  211.5000
# 411       1    0  37.0      1      0   90.0000
# 414       1    0  39.0      0      0  108.9000
#
# [87 rows x 6 columns]

# %%
y_test = df_test["Survived"]

# %%
y_test
# Out:
# 12     1
# 14     1
# 24     1
# 26     1
# 28     0
#       ..
# 404    0
# 405    0
# 407    0
# 411    1
# 414    1
# Name: Survived, Length: 87, dtype: int64

# %%
X_test = df_test.drop("Survived" , axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-2fc098d8b93c> in <module>
# ----> 1 X_test = df_test.drop("Survived" , axis = 1)
#
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\miniconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
predictions = logmodel.predict(df_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91        43
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.92        87
#    macro avg       0.93      0.92      0.92        87
# weighted avg       0.93      0.92      0.92        87
